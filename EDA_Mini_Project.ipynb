# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('fifa (1).csv')

# %%
df1=pd.read_csv('fifa_+variable_information.csv')

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
df1.head()
# Out:
#             ID     unique id for every player
# 0         Name                           name
# 1          Age                            age
# 2        Photo      url to the player's photo
# 3  Nationality                    nationality
# 4         Flag  url to players's country flag

# %%
df['Value']
# Out:
# 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
#           ...
# 18202       €60K
# 18203       €60K
# 18204       €60K
# 18205       €60K
# 18206       €60K
# Name: Value, Length: 18207, dtype: object

# %%
def func(x):
    x=x.replace('€','')
    if x[-1]=='M':
       return float(x[:-1])*1000000
    elif x[-1]=='K':
       return (float(x[:-1]))*1000

# %%
df['Value']=df['Value'].apply(func)

# %%
df['Value']
# Out:
# 0        110500000.0
# 1         77000000.0
# 2        118500000.0
# 3         72000000.0
# 4        102000000.0
#             ...
# 18202        60000.0
# 18203        60000.0
# 18204        60000.0
# 18205        60000.0
# 18206        60000.0
# Name: Value, Length: 18207, dtype: float64

# %%
df['Wage']
# Out:
# 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object

# %%
df['Wage']=df['Wage'].apply(func)

# %%
df['Wage']
# Out:
# 0        565000.0
# 1        405000.0
# 2        290000.0
# 3        260000.0
# 4        355000.0
#            ...
# 18202      1000.0
# 18203      1000.0
# 18204      1000.0
# 18205      1000.0
# 18206      1000.0
# Name: Wage, Length: 18207, dtype: float64

# %%
df['Joined']=pd.to_datetime(df['Joined']).dt.year

# %%
df['Joined']=df['Joined'].fillna(0)

# %%
df['Joined'].astype(int)
# Out:
# 0        2004
# 1        2018
# 2        2017
# 3        2011
# 4        2015
#          ...
# 18202    2017
# 18203    2018
# 18204    2017
# 18205    2018
# 18206    2018
# Name: Joined, Length: 18207, dtype: int32

# %%
df['Contract Valid Until']=pd.to_datetime(df['Contract Valid Until'])
df['Contract Valid Until']
# Out:
# 0       2021-01-01
# 1       2022-01-01
# 2       2022-01-01
# 3       2020-01-01
# 4       2023-01-01
#            ...
# 18202   2019-01-01
# 18203   2020-01-01
# 18204   2021-01-01
# 18205   2019-01-01
# 18206   2019-01-01
# Name: Contract Valid Until, Length: 18207, dtype: datetime64[ns]

# %%
df['Height']=df['Height'].str.replace("'",'.')

# %%
df['Height']=df['Height'].astype('float')
df['Height']
# Out:
# 0        5.70
# 1        6.20
# 2        5.90
# 3        6.40
# 4        5.11
#          ...
# 18202    5.90
# 18203    6.30
# 18204    5.80
# 18205    5.10
# 18206    5.10
# Name: Height, Length: 18207, dtype: float64

# %%
df['Release Clause']=df['Release Clause'].fillna('0')

# %%
df['Release Clause']=df['Release Clause'].apply(func)
df['Release Clause']
# Out:
# 0        226500000.0
# 1        127100000.0
# 2        228100000.0
# 3        138600000.0
# 4        196400000.0
#             ...
# 18202       143000.0
# 18203       113000.0
# 18204       165000.0
# 18205       143000.0
# 18206       165000.0
# Name: Release Clause, Length: 18207, dtype: float64

# %%
df1=df.describe()

# %%
df1
# Out:
#                   ID           Age       Overall     Potential         Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000  1.795500e+04
# mean   214298.338606     25.122206     66.238699     71.307299  2.444530e+06
# std     29965.244204      4.669943      6.908930      6.136496  5.626715e+06
# min        16.000000     16.000000     46.000000     48.000000  1.000000e+04
# 25%    200315.500000     21.000000     62.000000     67.000000  3.250000e+05
# 50%    221759.000000     25.000000     66.000000     71.000000  7.000000e+05
# 75%    236529.500000     28.000000     71.000000     75.000000  2.100000e+06
# max    246620.000000     45.000000     94.000000     95.000000  1.185000e+08
#
#                 Wage  International Reputation     Weak Foot   Skill Moves  \
# count   17966.000000              18159.000000  18159.000000  18159.000000
# mean     9861.850161                  1.113222      2.947299      2.361308
# ...

# %%
df1.columns
# Out:
# Index(['ID', 'Age', 'Overall', 'Potential', 'Value', 'Wage',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
#        'Joined', 'Height', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                         252
# Wage                          241
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                          0
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# ...

# %%
for i in df1.columns:
    if i in df.columns:
        df[i]=df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation        0
# Weak Foot                       0
# Skill Moves                     0
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                   0
# Joined                          0
# Loaned From                 16943
# Contract Valid Until          289
# Height                          0
# Weight                         48
# Crossing                        0
# Finishing                       0
# ...

# %%
df['Overall'].plot(kind='density')

# %%
l=['Overall', 'Value', 'Wage', 'International Reputation', 'Height', 'Weight', 'Release Clause']
df2=pd.DataFrame()
for i in l:
    df2[i]=df[i]
df2
# Out:
#        Overall        Value      Wage  International Reputation  Height  \
# 0           94  110500000.0  565000.0                       5.0    5.70
# 1           94   77000000.0  405000.0                       5.0    6.20
# 2           92  118500000.0  290000.0                       5.0    5.90
# 3           91   72000000.0  260000.0                       4.0    6.40
# 4           91  102000000.0  355000.0                       4.0    5.11
# ...        ...          ...       ...                       ...     ...
# 18202       47      60000.0    1000.0                       1.0    5.90
# 18203       47      60000.0    1000.0                       1.0    6.30
# 18204       47      60000.0    1000.0                       1.0    5.80
# 18205       47      60000.0    1000.0                       1.0    5.10
# 18206       46      60000.0    1000.0                       1.0    5.10
#
#        Weight  Release Clause
# 0      159lbs     226500000.0
# 1      183lbs     127100000.0
# ...

# %%
sns.pairplot(df2)

# %%
top_20=df[df['Contract Valid Until']=='2020-01-01'].sort_values('Overall',ascending=False).head(20)
top_20
# Out:
#          ID             Name  Age  \
# 3    193080           De Gea   27
# 6    177003        L. Modrić   32
# 8    155862     Sergio Ramos   32
# 5    183277        E. Hazard   27
# 13   168542      David Silva   32
# 21   179813        E. Cavani   31
# 24   138956     G. Chiellini   33
# 31   190460       C. Eriksen   26
# 39   164240     Thiago Silva   33
# 50   175943       D. Mertens   31
# 52   171877        M. Hamšík   30
# 49   189332       Jordi Alba   29
# 46   193041         K. Navas   31
# 64   191043      Alex Sandro   27
# 71   184087  T. Alderweireld   29
# 73   177509       M. Benatia   31
# 75   135507      Fernandinho   33
# 102  171919            Naldo   35
# 104  168609          Miranda   33
# 103  170890       B. Matuidi   31
#
#                                               Photo Nationality  \
# 3    https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 6    https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# ...

# %%
top_20['Wage'].mean()
# Out:
# 205450.0

# %%
top_20['Age'].mean()
# Out:
# 30.65

# %%
top_20[['Overall','Value']].corr()
#Positively correlated
# Out:
#           Overall     Value
# Overall  1.000000  0.786717
# Value    0.786717  1.000000

# %%
position=df['Position'].unique()
position
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB', nan], dtype=object)

# %%
s=pd.DataFrame()
for i in position:
    s=pd.concat([s,df[df['Position']==i].sort_values(['Overall']).head(5)])
s
# Out:
#            ID            Name  Age  \
# 10110  207659     L. Grozurek   26
# 9388   157321       K. Tamada   38
# 9506   232609      G. Notsuda   24
# 6662   206605       A. Aosman   23
# 6108   224385       H. Yamada   29
# ...       ...             ...  ...
# 18070  236705    E. Dahlqvist   19
# 17401  244864  F. Fridriksson   19
# 16863  243608        R. Giles   18
# 16937  233931       K. Rowles   20
# 16374  232267          Lu Yao   25
#
#                                                 Photo Nationality  \
# 10110  https://cdn.sofifa.org/players/4/19/207659.png     Austria
# 9388   https://cdn.sofifa.org/players/4/19/157321.png       Japan
# 9506   https://cdn.sofifa.org/players/4/19/232609.png       Japan
# 6662   https://cdn.sofifa.org/players/4/19/206605.png       Syria
# 6108   https://cdn.sofifa.org/players/4/19/224385.png       Japan
# ...                                               ...         ...
# 18070  https://cdn.sofifa.org/players/4/19/236705.png      Sweden
# ...

# %%
s['Name'].duplicated().value_counts()
# no players appeared in different positions
# Out:
# False    135
# Name: Name, dtype: int64

# %%
s1=s.groupby('Position')

# %%
s1['Wage'].mean()
# Out:
# Position
# CAM    1000.000000
# CB     1000.000000
# CDM    1000.000000
# CF     1000.000000
# CM     1000.000000
# GK     1000.000000
# LAM    3800.000000
# LB     1000.000000
# LCB    1000.000000
# LCM    1800.000000
# LDM    2972.370032
# LF     2600.000000
# LM     1200.000000
# LS     1400.000000
# LW     1000.000000
# LWB    1600.000000
# RAM    4000.000000
# RB     1000.000000
# RCB    1000.000000
# RCM    1200.000000
# RDM    1200.000000
# RF     4200.000000
# RM     1200.000000
# RS     2000.000000
# RW     1200.000000
# RWB    1000.000000
# ST     1000.000000
# Name: Wage, dtype: float64
